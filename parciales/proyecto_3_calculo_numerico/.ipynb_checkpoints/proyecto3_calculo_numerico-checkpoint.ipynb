# %%
import pandas as pd
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
# Importacion de librerias

# Carga de datos de muestra del archivo CSV
df = pd.read_csv("datos.csv")
x1 = df.iloc[:, 0]
x1 = np.array(x1)
y1 = df.iloc[:, 1]
y1 = np.array(y1)
xvals1 = df.iloc[:, 2]
xvals1 = np.array(xvals1[:3])

x2 = df.iloc[:, 3]
x2 = np.array(x2[:5])
y2 = df.iloc[:, 4]
y2 = np.array(y2[:5])
xvals2 = df.iloc[:, 5]
xvals2 = np.array(xvals2[:3])

a11 = df.iloc[:, 6]
a21 = df.iloc[:, 7]
a31 = df.iloc[:, 8]
A = np.array([a11[:3], a21[:3], a31[:3]])
b = df.iloc[:, 9]
b = np.array(b[:3])

# %%
def trazador_cubico(xi, yi):
    n = len(xi)
    
    # Valores h
    h = np.zeros(n-1, dtype=float)
    for j in range(0, n-1):
        h[j] = xi[j+1] - xi[j]
    
    # Sistema de ecuaciones
    A = np.zeros(shape=(n, n), dtype=float)
    B = np.zeros(n, dtype=float)
    
    A[0, 0] = 1
    A[n-1, n-1] = 1
    
    for i in range(1, n-1):
        A[i, i-1] = h[i-1]
        A[i, i] = 2 * (h[i-1] + h[i])
        A[i, i+1] = h[i]
        B[i] = 6 * ((yi[i+1] - yi[i]) / h[i] - (yi[i] - yi[i-1]) / h[i-1])
    
    # Resolver sistema de ecuaciones S
    S = np.linalg.solve(A, B)
    
    # Coeficientes
    a = np.zeros(n-1, dtype=float)
    b = np.zeros(n-1, dtype=float)
    c = np.zeros(n-1, dtype=float)
    d = np.zeros(n-1, dtype=float)
    
    for j in range(0, n-1):
        a[j] = (S[j+1] - S[j]) / (6 * h[j])
        b[j] = S[j] / 2
        c[j] = (yi[j+1] - yi[j]) / h[j] - (2 * h[j] * S[j] + h[j] * S[j+1]) / 6
        d[j] = yi[j]
    
    # Polinomios por tramos
    x = sym.Symbol('x')
    px_tabla = []
    
    for j in range(0, n-1):
        pxtramo = a[j] * (x - xi[j])**3 + b[j] * (x - xi[j])**2 + c[j] * (x - xi[j]) + d[j]
        pxtramo = pxtramo.expand()
        px_tabla.append(pxtramo)
        
        # Imprimir polinomio por tramo
        print(f'Polinomio en el intervalo [{xi[j]}, {xi[j+1]}]:')
        print(pxtramo)
        print()  # línea en blanco para separar los polinomios
    
    return px_tabla

# %%
def gauss_jordan(A):
    Ab = A
    n = len(Ab)

    for i in range(n):  
        Ab[i]/=Ab[i][i]
        for j in range(i+1, n):
            factor = Ab[j][i]
            Ab[j] -= factor * Ab[i]
        
    for i in range(n-1, -1, -1):
        for j in range(i-1, -1, -1):
            factor = Ab[j][i]
            Ab[j] -= factor * Ab[i]
           
    solucion=[]
    for i in range(0,len(Ab[0])-1):
        solucion.append(Ab[i][len(Ab[0])-1])
    return solucion

#metodo que devuelve la matriz aumentada de coeficientes con las variables a1, a2...,an a resolver
def minimos_cuadrados(x, y, n):
    #array auxiliar que usaremos para llenar las filas de la matriz resultado
    array_auxiliar = np.zeros(n+1, dtype=float)
    resultado = np.zeros((n, n+1), dtype=float)
    # ciclo que va de 0 a n para ir llenando la matriz resultado y el array auxiliar
    for i in range(n):
        #ciclo de 0 a n+1 que llena el array auxiliar en relacion a su posicion
        for j in range(n+1):
            #si i es 0 y j es 0 debemos poner el tamaño del array de datos x en la posicion [0][0] de la matriz resultado
            if i == 0:
                if j == 0:
                    array_auxiliar[j] = len(x)
                #cuando j es igual a n agregamos el termino independiente que seria la suma de el array y
                elif j == n:
                    array_auxiliar[j] = np.sum(y)
                #cuando j es distinto de n y 0 se agrega la suma de el array x elevado al valor de j
                else:
                    array_auxiliar[j] = np.sum(x**j)
            #si i es distinto de 0 sigue su curso normal
            else:
                #en este caso cuando j es igual a n se tiene que agregar el termino independiente pero expresado como la suma de x a la i por y
                if j == n:
                    array_auxiliar[j] = np.sum((x**i) * y)
                #si j es distinto de n se agregan los coeficientes de a0, a1...,an expresados como la suma de x a la i+j
                else:
                    array_auxiliar[j] = np.sum(x**(i+j))
        #se agrega el array auxiliar a las filas de la matriz resultado
        resultado[i] = array_auxiliar
    #se devuelve la matriz resultado al estar llena
    return resultado

# %%
#funcion que calcula el polinomio de chebyshev de grado "grado" a partir de su ecuacion de recurrencia
def chebyshev(grado):
    #si grado es 0 retorna 1
    if grado == 0:
        return np.poly1d([1])
    #si grado es 1 retorna x
    elif grado == 1:
        return np.poly1d([1, 0])
    #si grado es mayor a 1 se calcula el polinomio recursivamente
    else:
        return 2 * np.poly1d([1, 0]) * chebyshev(grado - 1) - chebyshev(grado - 2)

# %%
def fuerzasPcriticos(A, b):
    Ab = np.hstack((A, b.reshape(-1, 1)))
    fuerzas = np.array(gauss_jordan(Ab))
    print(f"\nPC1: {fuerzas[0]}")
    print(f"PC2: {fuerzas[1]}")
    print(f"PC3: {fuerzas[2]}\n")

# %%
def menu(y2):
    cont = True
    while cont:
        print("Diseño de montaña rusa:\n")
        print("1. Ver la gráfica de la trayectoria")
        print("2. Ver la gráfica de la curva ajustada")
        print("3. Ver la gráfica de la trayectoria optimizada")
        print("4. Ver los las fuerzas en los puntos críticos")
        op = input("Ingrese el número de la gráfica que desea ver: ")

        if op == "1":
            
            # Datos de prueba (x_data, y_data) para graficar la curva
            x_data = x1
            y_data = y1
            
            # Tabla de polinomios por tramos con el trazador cúbico sujeto
            px_tabla = trazador_cubico(x_data, y_data)
            
            # Puntos para graficar cada tramo
            x_vals = np.linspace(xvals1[0], xvals1[1], xvals1[2])
            y_vals = np.zeros_like(x_vals)
            
            # Evaluar polinomio por tramos y construir la curva
            tramo = 0
            while tramo < len(px_tabla):
                pxt = sym.lambdify('x', px_tabla[tramo])
                mask = np.where((x_vals >= x_data[tramo]) & (x_vals <= x_data[tramo+1]))
                y_vals[mask] = pxt(x_vals[mask])
                tramo += 1
            
            # Gráfica
            plt.figure(figsize=(8, 6))
            plt.plot(x_data, y_data, 'ro', label='Puntos de datos')
            plt.plot(x_vals, y_vals, label='Trazador cúbico sujeto', color='blue')
            plt.title('Trazador Cúbico Sujeto para la Trayectoria de la Montaña Rusa')
            plt.xlabel('x')
            plt.ylabel('y')
            plt.legend()
            plt.grid(True)
            plt.show()            
            c = input("Ingrese 1 para continuar, ingrese 0 para cerrar el programa")
            if c == "0":
                cont = False
            else:
                print("Número inválido, se cargará el menú otra vez.")
        elif op == "2":
            #datos experimentales de tensiones y compresiones     
            xi = x2
            yi = y2
            # Valores para graficar la curva ajustada
            datos_x = np.linspace(xvals2[0], xvals2[1], xvals2[2])
            datos_y = np.zeros(len(datos_x))
            #variable simbolica x 
            x=sym.Symbol("x")
            #numero de terminos del polinomio de minimos cuadrados
            n=4
            #array que contiene las soluciones de la matriz de coeficientes de a
            resolucion= gauss_jordan(minimos_cuadrados(xi,yi,n))
            #variable en donde guardaremos el termino del polinomio 
            polinomio=0
            #ciclo en donde iremos guardando los terminos del polinomio en la variable polinomio
            for i in range(0,len(resolucion)):
                if i == 0:
                    polinomio+=resolucion[i]
                else:
                    polinomio+=resolucion[i]*(x**i)
            #ciclo en donde iremos evaluando los puntos de datos_x en el polinomio para obtener los datos_y
            for i in range(0,len(datos_y)):
                if isinstance(polinomio, np.float64): 
                    datos_y[i]=polinomio
                else:
                    datos_y[i]=polinomio.subs(x,datos_x[i])
            #polinomio alternativo para graficar las lineas de error
            polinomio_error = sym.lambdify(x, polinomio, modules=["numpy"])
            #datos_y de las lineas de error
            datos_y_error = polinomio_error(datos_x)
            
            #datos de la grafica
            plt.plot(xi,yi,'o',label="Datos experimentales")
            plt.title("Paso 2: polinomio de minimos cuadrados")
            plt.xlabel("Tensiones")
            plt.ylabel("Compresiones")
            plt.plot(datos_x,datos_y,label="Curva ajustada")
            #lineas de error
            for i in range(len(xi)):
                y = np.min([yi[i], polinomio_error(xi[i])])
                y2 = np.max([yi[i], polinomio_error(xi[i])])
                plt.vlines(xi[i], y, y2, color='green', linestyle='dotted')
            plt.vlines(xi[0], np.min([yi[0], polinomio_error(xi[0])]), np.max([yi[0], polinomio_error(xi[0])]), color='green', linestyle='dotted',label="Lineas de error")
            plt.legend()
            plt.show()
            
            c = input("Ingrese 1 para continuar, ingrese 0 para cerrar el programa")
            if c == "0":
                cont = False
            else:
                print("Número inválido, se cargará el menú otra vez.")
        elif op == "3":
            #funcion que retorna la funcion que describe a los datos originales
            def funcion_datos_originales(x, y):
                return np.poly1d(np.polyfit(x, y, deg=len(x) - 1))
            #datos originales
            x = np.array(x1)
            y = np.array(y1)
            #datos a graficar
            x_data = np.linspace(xvals1[0], xvals1[1], xvals1[2])
            #grado del polinomio de chebyshev
            grado = 5
            #array que guarda las raices del polinomio de chebyshev
            xi = chebyshev(grado).r
            #array que se escala de [-1,1] hasta [0,5] (intervalo de los datos originales)
            xi_escalado = 0.5 * (xi + 1) * (x.max() - x.min()) 
            #array que guarda cada valor que devuelve de la funcion de los datos originales al ser evaluados por cada valor del array escalado
            yi = funcion_datos_originales(x, y)(xi_escalado)
            #se crea el polinomio ajustado 
            c2 = np.polyfit(xi_escalado, yi, grado-1)
            poli2 = np.poly1d(c2)
            
            #graficos 
            plt.plot(x_data, funcion_datos_originales(x, y)(x_data), color="green", label="Tramo original de la montaña rusa")
            plt.plot(x_data, poli2(x_data), color="blue", label="Tramo de la montaña ajustado con polinomio de chebyshev")
            plt.xlabel("X")
            plt.ylabel("Y")
            plt.title("Paso 3: polinomios ortogonales")
            plt.legend()
            plt.show()
            c = input("Ingrese 1 para continuar, ingrese 0 para cerrar el programa")
            if c == "0":
                cont = False
            else:
                print("Número inválido, se cargará el menú otra vez.")
        elif op == "4":
            fuerzasPcriticos(A, b)
            c = input("Ingrese 1 para continuar, ingrese 0 para cerrar el programa")
            if c == "0":
                cont = False
            else:
                print("Número inválido, se cargará el menú otra vez.")
        else:
            print("Número inválido, ingrese un número correspondiente a una gráfica.")

# %%
menu(y2)
# Out:
# Diseño de montaña rusa:
#
# 1. Ver la gráfica de la trayectoria
# 2. Ver la gráfica de la curva ajustada
# 3. Ver la gráfica de la trayectoria optimizada
# 4. Ver los las fuerzas en los puntos críticos
# Ingrese el número de la gráfica que desea ver:  4
# PC1: -0.19999999999999973
# PC2: 0.9333333333333331
# PC3: 2.3333333333333335
# Ingrese 1 para continuar, ingrese 0 para cerrar el programa 0
